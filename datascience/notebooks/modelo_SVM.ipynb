# %% [markdown]
# # 🧠 TechMind
# # Organização Inteligente de Conhecimento Técnico

# %% [markdown]
# ## O Projeto

# %% [markdown]
# Criar uma solução (MVP funcional) que permita o enriquecimento e a organização inteligente de conteúdo técnico, facilitando sua classificação, consulta e reutilização.
#
# A solução deve utilizar técnicas de Ciência de Dados e integração com uma API

# %% [markdown]
# ## Objetivo

# %% [markdown]
# • Criar e treinar modelos de classificação por categoria técnica
#
# • Avaliar modelos e disponibilizar o de melhor performance para ser consumido via API
#
# • Extração de palavras-chave
#
# • Serialização do modelo e geração de .pkl

# %% [markdown]
# ## Bibliotecas

# %%
# Importa as Bibliotecas

# Manipulação de dados
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import joblib
import json

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.svm import SVC

# %% [markdown]
# ## Obtendo Dados

# %%
# Carregando dados 
df = pd.read_csv('../dados/base_techmind.csv')
df.sample(5)
# Out:
#                                                   texto categoria
# 1396  explore loop . learn - loop . cover traditiona...   Backend
# 1249  disclosure build schemity desktop erd tool - p...  Database
# 355   sanity wordpress content management build new ...   Backend
# 1151  ghsa - qqm - fpq - v authorization bypass skip...  Security
# 363   add widget site tool hand iframe little seal w...  Frontend

# %% [markdown]
# ### Conhecendo Dados e Estruturas

# %%
# Conhecendo dados e estrutura
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1564 entries, 0 to 1563
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   texto      1564 non-null   str
#  1   categoria  1564 non-null   str
# dtypes: str(2)
# memory usage: 6.2 MB

# %%
# Conferindo dados
df['categoria'].value_counts()
# Out:
# categoria
# Backend        319
# Security       301
# Database       268
# Frontend       252
# Cloud          240
# DataScience    184
# Name: count, dtype: int64

# %% [markdown]
# ## Pré Modelagem

# %%
# Base para modelagem
df_model = df.copy()
df_model.shape
# Out:
# (1564, 2)

# %% [markdown]
# ### Separação de Dados

# %% [markdown]
# Divisão da base em conjuntos de treino (80%) e teste (20%), utilizando `stratify=categoria` para preservar a proporção de cada categoria em ambos os conjuntos. Isso é importante devido o desbalanceamento entre classes (ex: DataScience possui bem menos registros que Backend).

# %%
# Split treino/teste (estratificado)
X_train, X_test, y_train, y_test = train_test_split(
    df_model['texto'],
    df_model['categoria'],
    test_size=0.2,
    random_state=42,
    stratify=df_model['categoria']
)

print(X_train.shape, X_test.shape)
# Out:
# (1251,) (313,)

# %%
# Validando proporção das categorias para treino (stratify)
print(y_train.value_counts(normalize=True))

# Validando proporção das categorias para teste (stratify)
print(y_test.value_counts(normalize=True))
# Out:
# categoria
# Backend        0.203837
# Security       0.192646
# Database       0.171063
# Frontend       0.161471
# Cloud          0.153477
# DataScience    0.117506
# Name: proportion, dtype: float64
# categoria
# Backend        0.204473
# Security       0.191693
# Database       0.172524
# Frontend       0.159744
# Cloud          0.153355
# DataScience    0.118211
# Name: proportion, dtype: float64

# %% [markdown]
# Conferência das proporções de cada categoria em `y_train` e `y_test` para garantir que o `stratify` manteve a distribuição original da base. As proporções ficaram praticamente idênticas entre os dois conjuntos, confirmando que o split foi feito corretamente.

# %% [markdown]
# ### TF-IDF (vetorização)

# %% [markdown]
# Transformação dos textos em vetores numéricos usando TF-IDF (Term Frequency - Inverse Document Frequency), que atribui peso maior a termos relevantes e discriminativos para cada categoria, e peso menor a termos muito comuns.
#
# O vetorizador é ajustado (`fit_transform`) apenas nos dados de treino, e aplicado (`transform`) nos dados de teste, evitando vazamento de informação do teste para o treino.

# %%
# TF-IDF Vectorization
vectorizer = TfidfVectorizer(
    max_features=5000,
    ngram_range=(1, 2)
)

X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

print(X_train_tfidf.shape, X_test_tfidf.shape)
# Out:
# (1251, 5000) (313, 5000)

# %% [markdown]
# Parâmetros escolhidos:
# - `max_features=5000`: limita o vocabulário aos 5000 termos mais relevantes, evitando ruído de palavras raras
# - `ngram_range=(1, 2)`: considera palavras isoladas e pares de palavras, capturando um pouco mais de contexto
#
# *(stopwords não são reaplicadas aqui pois já foram removidas na limpeza via spaCy)*

# %% [markdown]
# ## Modelo Logistic Regression

# %% [markdown]
# ### Modelagem - Logistic Regression (baseline)

# %% [markdown]
# #### Criação do Modelo

# %%
# Cria modelo de classificação 
modelo_lr = LogisticRegression(
    max_iter=1000, 
    random_state=42
)

# %% [markdown]
# #### Validação Cruzada (Cross-Validation)

# %% [markdown]
# Antes de avaliar o modelo no conjunto de teste, aplicamos validação cruzada (5-fold) nos dados de treino para verificar se o desempenho do modelo é consistente, evitando conclusões baseadas em um único split.
#
# Utilizamos `f1_macro` como métrica, por ponderar igualmente todas as categorias, mais adequada que a acurácia dado o desbalanceamento da base.

# %%
scores_lr = cross_val_score(
    modelo_lr, X_train_tfidf, y_train, cv=5, scoring='f1_macro'
)

print(f"F1 macro: {scores_lr.mean():.4f} (+/- {scores_lr.std():.4f})")
# Out:
# F1 macro: 0.7925 (+/- 0.0162)

# %% [markdown]
# A validação cruzada apresentou F1 macro médio de 0.7925, com desvio padrão de 0.0162 entre os 5 folds. O desvio baixo indica que o desempenho do modelo Logistic Regression é consistente independente de quais dados caem em cada fold, reforçando a confiabilidade do resultado antes de avaliarmos o modelo no conjunto de teste.

# %% [markdown]
# #### Treinamento do modelo

# %%
# Treino do modelo Logistic Regression
modelo_lr.fit(
    X_train_tfidf,
    y_train
)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %% [markdown]
# #### Avaliação do Modelo  - Logistic Regression (baseline)

# %% [markdown]
# Avaliação do desempenho do modelo nos dados de teste, utilizando métricas por categoria (precision, recall, F1-score), já que a base possui desbalanceamento entre classes o accuracy geral sozinho não seria suficiente para avaliar corretamente o modelo.

# %%
# Predição nos dados de teste
y_pred_lr = modelo_lr.predict(X_test_tfidf)

# %%
# Métricas de avaliação
print(classification_report(y_test, y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#      Backend       0.72      0.75      0.73        64
#        Cloud       0.87      0.81      0.84        48
#  DataScience       0.89      0.68      0.77        37
#     Database       0.91      0.91      0.91        54
#     Frontend       0.73      0.72      0.73        50
#     Security       0.81      0.95      0.88        60
#
#     accuracy                           0.81       313
#    macro avg       0.82      0.80      0.81       313
# weighted avg       0.81      0.81      0.81       313

# %% [markdown]
# O modelo de Regressão Logística obteve 81% de acurácia no conjunto de teste, resultado consistente com o F1 macro de 0.7918 estimado na validação cruzada. Como a base apresenta desbalanceamento entre categorias, a análise por classe (precision, recall e F1-score) é mais informativa que a acurácia geral isoladamente:
#
# * Melhor desempenho (F1 ≥ 0.90): Database (F1 0.91)
# * Desempenho intermediário (F1 ≥ 0.80): Security (F1 0.88) e Cloud (F1 0.84)
# * Menor desempenho (F1 < 0.80): DataScience (F1 0.77), Backend (F1 0.73) e Frontend (F1 0.73)
#
# DataScience, mesmo sendo a categoria com menos registros de treino, apresentou recall de 0.68 e F1 de 0.77, um bom resultado considerando o desbalanceamento da base.
#
# As métricas macro avg (média simples entre categorias) e weighted avg (média ponderada pelo número de exemplos de cada categoria) ficaram iguais (0.81), reforçando que o desempenho está equilibrado entre as categorias, apesar do desbalanceamento da base.

# %% [markdown]
# ##### Matriz de Confusão

# %% [markdown]
# Visualização de quais categorias o modelo mais confunde entre si, complementando a análise de precision/recall por classe.

# %%
cm = confusion_matrix(y_test, y_pred_lr, labels=modelo_lr.classes_)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=modelo_lr.classes_, yticklabels=modelo_lr.classes_)
plt.xlabel('Predito')
plt.ylabel('Real')
plt.title('Matriz de Confusão - Logistic Regression (Baseline)')
plt.show()

# %% [markdown]
# A matriz de confusão confirma o padrão observado nas métricas:
#
# * A confusão está espalhada entre as categorias, sem um padrão dominante.
# * A maior concentração de erros ocorre entre Frontend e Backend (10 casos de Frontend classificados como Backend), sugerindo sobreposição de vocabulário técnico entre essas categorias.
# * Security e Cloud, por outro lado, apresentam baixíssima confusão cruzada, confirmando seu bom desempenho.

# %% [markdown]
# O modelo baseline de Regressão Logística obteve um desempenho consistente (81% de acurácia, F1 macro 0.81), sem nenhuma categoria com fragilidade evidente.
#
# Ainda assim, testaremos o modelo com o parâmetro class_weight='balanced', que ajusta o peso das classes durante o treino de forma inversamente proporcional à frequência de cada categoria, para verificar se esse ajuste traz algum ganho adicional em categorias com menos registros, como DataScience.

# %% [markdown]
# ### Modelagem - Logistic Regression (com class_weight='balanced')

# %% [markdown]
# #### Criando Modelo

# %%
# Criando modelo 
modelo_lr_balanced = LogisticRegression(max_iter=1000, 
                                        random_state=42, 
                                        class_weight='balanced')

# %% [markdown]
# #### Validação Cruzada (Cross-Validation) - Modelo com class_weight='balanced'

# %%
# Cross-validation
scores_lr_balanced = cross_val_score(
    modelo_lr_balanced, X_train_tfidf, y_train, cv=5, scoring='f1_macro'
)

print(f"F1 macro: {scores_lr_balanced.mean():.4f} (+/- {scores_lr_balanced.std():.4f})")
# Out:
# F1 macro: 0.8088 (+/- 0.0156)

# %% [markdown]
# A validação cruzada do modelo com class_weight='balanced' apresentou F1 macro médio de 0.8088, com desvio padrão de 0.0156 entre os 5 folds. Comparado ao baseline (F1 macro 0.7925, desvio 0.0162), o modelo balanced teve desempenho médio superior e leve redução na variação entre os folds, o que reforça a decisão de avançar com essa configuração para a avaliação final no conjunto de teste.

# %% [markdown]
# #### Treinamento do modelo

# %%
# Treino
modelo_lr_balanced.fit(X_train_tfidf, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42)

# %% [markdown]
# ### Comparação - Avaliação dos Modelos Logistic Regression

# %%
# Predição Modelo com balanced
y_pred_lr_balanced = modelo_lr_balanced.predict(X_test_tfidf)

# %%
# Métricas de avaliação dos modelos (sem e com class_weight='balanced') 

# Gerando os relatórios como DataFrame
report_baseline = pd.DataFrame(classification_report(y_test, y_pred_lr, output_dict=True)).transpose()
report_balanced = pd.DataFrame(classification_report(y_test, y_pred_lr_balanced, output_dict=True)).transpose()

# Comparando performance dos dois modelos
comparacao = pd.concat([report_baseline, report_balanced], axis=1, keys=['Baseline', 'Balanced'])
comparacao.round(2)
# Out:
#               Baseline                          Balanced                  \
#              precision recall f1-score support precision recall f1-score
# Backend           0.72   0.75     0.73   64.00      0.78   0.67     0.72
# Cloud             0.87   0.81     0.84   48.00      0.85   0.85     0.85
# DataScience       0.89   0.68     0.77   37.00      0.71   0.73     0.72
# Database          0.91   0.91     0.91   54.00      0.88   0.91     0.89
# Frontend          0.73   0.72     0.73   50.00      0.73   0.76     0.75
# Security          0.81   0.95     0.88   60.00      0.84   0.90     0.87
# accuracy          0.81   0.81     0.81    0.81      0.81   0.81     0.81
# macro avg         0.82   0.80     0.81  313.00      0.80   0.80     0.80
# weighted avg      0.81   0.81     0.81  313.00      0.80   0.81     0.80
#
#
#              support
# Backend        64.00
# Cloud          48.00
# DataScience    37.00
# Database       54.00
# Frontend       50.00
# Security       60.00
# accuracy        0.81
# macro avg     313.00
# weighted avg  313.00

# %% [markdown]
# A tabela comparativa mostra que os dois modelos tiveram a mesma acurácia (0.81). No macro avg, o F1-score foi levemente menor no balanced (0.80) em relação ao baseline (0.81), embora o recall médio tenha sido um pouco maior (0.81 contra 0.80) e a precision média menor (0.80 contra 0.82).
#
# Em DataScience, o balanced trouxe um trade-off: o recall subiu de 0.68 para 0.73, mas a precision caiu de 0.89 para 0.71, resultando em um F1-score menor (de 0.77 para 0.72).
#
# Em Backend, aconteceu o oposto: a precision subiu de 0.72 para 0.80, enquanto o recall caiu de 0.75 para 0.67, mantendo o F1-score praticamente igual (0.73 nos dois modelos).
#
# Nas demais categorias, as variações foram pequenas: Cloud (F1 0.84 para 0.85) e Frontend (F1 0.73 para 0.76) melhoraram levemente, enquanto Database (F1 0.91 para 0.89) e Security (F1 0.88 para 0.87) caíram um pouco.
#
# No geral, o balanceamento não trouxe ganho evidente nessa base.

# %% [markdown]
# #### Comparação - Matriz de Confusão

# %%
# Comparando as matrizes de confusão 
cm = confusion_matrix(y_test, y_pred_lr, labels=modelo_lr.classes_)
cm_balanced = confusion_matrix(y_test, y_pred_lr_balanced, labels=modelo_lr_balanced.classes_)

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=modelo_lr.classes_, yticklabels=modelo_lr.classes_,
            ax=axes[0])
axes[0].set_xlabel('Predito')
axes[0].set_ylabel('Real')
axes[0].set_title('Logistic Regression (Baseline)')

sns.heatmap(cm_balanced, annot=True, fmt='d', cmap='Blues',
            xticklabels=modelo_lr_balanced.classes_, yticklabels=modelo_lr_balanced.classes_,
            ax=axes[1])
axes[1].set_xlabel('Predito')
axes[1].set_ylabel('Real')
axes[1].set_title('Logistic Regression (Balanced)')

plt.tight_layout()
plt.show()

# %% [markdown]
# Comparando as duas matrizes, DataScience teve mais acertos no balanced (27 contra 25 no baseline), e a confusão com Backend caiu de 4 para 2 casos.
#
# Em compensação, Backend teve menos acertos no balanced (43 contra 48 no baseline), recebendo mais confusão vinda de Frontend (8 casos, contra 7 no baseline). A confusão entre DataScience e Backend, por outro lado, diminuiu nos dois sentidos.
#
# Cloud e Security permaneceram com padrão parecido nos dois modelos, com pequenas variações pontuais.

# %% [markdown]
# Conclusão - Modelo Logistic Regression
#
# Comparando os dois modelos, o balanceamento não trouxe ganho real nessa base já mais equilibrada após a limpeza.
#
# Em DataScience, o ganho de recall veio acompanhado de uma queda maior na precision, reduzindo o F1 da categoria.
#
# Em Backend, o ganho de precision veio acompanhado de uma queda equivalente no recall, mantendo o F1 praticamente igual.
#
# No resultado geral, essas trocas não se traduziram em melhora. O F1 macro do balanced ficou levemente abaixo do baseline (0.80 contra 0.81).
#
# Considerando essas informações, o modelo baseline será considerado o modelo final da Regressão Logística.

# %% [markdown]
# ## Modelo Naive Bayes

# %% [markdown]
# ## Modelo SVM

# %% [markdown]
# ### Modelagem - SVM (baseline)

# %% [markdown]
# #### Criação do Modelo

# %%
# Cria modelo de classificação SVM (baseline)
modelo_svm = SVC(
    kernel='linear', 
    random_state=42
)

# %% [markdown]
# #### Validação Cruzada (Cross-Validation)

# %% [markdown]
# Antes de avaliar o modelo no conjunto de teste, aplicamos validação cruzada (5-fold) nos dados de treino para verificar se o desempenho do modelo é consistente, evitando conclusões baseadas em um único split.
#
# Utilizamos `f1_macro` como métrica, por ponderar igualmente todas as categorias, mais adequada que a acurácia dado o desbalanceamento da base.

# %%
# Cross-validation SVM (baseline)
scores_svm = cross_val_score(
    modelo_svm, X_train_tfidf, y_train, cv=5, scoring='f1_macro'
)

print(f"F1 macro: {scores_svm.mean():.4f} (+/- {scores_svm.std():.4f})")
# Out:
# F1 macro: 0.7991 (+/- 0.0226)

# %% [markdown]
# A validação cruzada apresentou F1 macro médio de 0.7991, com desvio padrão de 0.0226 entre os 5 folds. O desvio baixo indica que o desempenho do modelo SVM é consistente independente de quais dados caem em cada fold, reforçando a confiabilidade do resultado antes de avaliarmos o modelo no conjunto de teste.

# %% [markdown]
# #### Treinamento do modelo

# %%
# Treino do modelo SVM (baseline)
modelo_svm.fit(
    X_train_tfidf,
    y_train
)
# Out:
# SVC(kernel='linear', random_state=42)

# %% [markdown]
# #### Avaliação do Modelo  - SVM (baseline)

# %% [markdown]
# Avaliação do desempenho do modelo nos dados de teste, utilizando métricas por categoria (precision, recall, F1-score), já que a base possui desbalanceamento entre classes o accuracy geral sozinho não seria suficiente para avaliar corretamente o modelo.

# %%
# Predição nos dados de teste SVM (baseline)
y_pred_svm = modelo_svm.predict(X_test_tfidf)

# %%
# Métricas de avaliação SVM (baseline)
print(classification_report(y_test, y_pred_svm))
# Out:
#               precision    recall  f1-score   support
#
#      Backend       0.68      0.73      0.71        64
#        Cloud       0.84      0.79      0.82        48
#  DataScience       0.81      0.70      0.75        37
#     Database       0.89      0.87      0.88        54
#     Frontend       0.76      0.78      0.77        50
#     Security       0.86      0.90      0.88        60
#
#     accuracy                           0.80       313
#    macro avg       0.81      0.80      0.80       313
# weighted avg       0.80      0.80      0.80       313

# %% [markdown]
# O modelo SVM obteve 80% de acurácia no conjunto de teste, resultado consistente com o F1 macro de 0.7991 estimado na validação cruzada. Como a base apresenta desbalanceamento entre categorias, a análise por classe (precision, recall e F1-score) é mais informativa que a acurácia geral isoladamente:
#
# * Melhor desempenho (F1 < 0.90): Database (F1 0.88) e Security (F1 0.88)
# * Desempenho intermediário (F1 ≥ 0.80): Cloud (F1 0.82)
# * Menor desempenho (F1 < 0.80): Frontend (F1 0.77), DataScience (F1 0.75) e Backend (F1 0.71)
#
# DataScience, mesmo sendo a categoria com menos registros de treino, apresentou recall de 0.70 e F1 de 0.75, um bom resultado considerando o desbalanceamento da base.
#
# As métricas macro avg (média simples entre categorias) e weighted avg (média ponderada pelo número de exemplos de cada categoria) ficaram iguais (0.80), reforçando que o desempenho está equilibrado entre as categorias, apesar do desbalanceamento da base.

# %% [markdown]
# ##### Matriz de Confusão

# %% [markdown]
# Visualização de quais categorias o modelo mais confunde entre si, complementando a análise de precision/recall por classe.

# %%
# Matriz Confusão SVM (baseline)
cm = confusion_matrix(y_test, y_pred_svm, labels=modelo_svm.classes_)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=modelo_svm.classes_, yticklabels=modelo_svm.classes_)
plt.xlabel('Predito')
plt.ylabel('Real')
plt.title('Matriz de Confusão - SVM (Baseline)')
plt.show()

# %% [markdown]
# A matriz de confusão confirma o padrão observado nas métricas:
#
# * A maior confusão pontual ocorre no `Frontend`: 9 textos da categoria `Frontend` foram incorretamente classificados como `Backend`, o que sugere sobreposição de vocabulário técnico entre essas duas áreas.
# * `Backend` é a classe com maior dispersão de erros: Além de receber falsos positivos de outras categorias, seus textos reais foram pulverizados entre `Frontend` (6 casos), `Database` (5 casos), `Cloud` (3 casos), `Security` (2 casos) e `DataScience` (1 caso).
# * `Security` e `Cloud` apresentam excelente separação: A classe `Security` obteve o maior número de acertos absolutos (54), apresentando baixíssima confusão cruzada com as demais categorias..

# %% [markdown]
# ### Modelagem - SVM (com class_weight='balanced')

# %% [markdown]
# #### Criando Modelo

# %%
# Cria modelo de classificação SVM (balanced)
modelo_svm_balanced = SVC(
    kernel='linear', 
    class_weight='balanced',
    random_state=42
)

# %% [markdown]
# #### Validação Cruzada (Cross-Validation) - Modelo com class_weight='balanced'

# %%
# Cross-validation SVM (balanced)
scores_svm_balanced = cross_val_score(
    modelo_svm_balanced, X_train_tfidf, y_train, cv=5, scoring='f1_macro'
)

print(f"F1 macro: {scores_svm_balanced.mean():.4f} (+/- {scores_svm_balanced.std():.4f})")
# Out:
# F1 macro: 0.8002 (+/- 0.0189)

# %% [markdown]
# A validação cruzada do modelo com class_weight='balanced' apresentou F1 macro médio de 0.8002, com desvio padrão de 0.0189 entre os 5 folds. Comparado ao baseline (F1 macro 0.7991, desvio padrão 0.0226), o modelo balanced teve desempenho médio superior e  redução na variação entre os folds, o que reforça a decisão de avançar com essa configuração para a avaliação final no conjunto de teste.

# %% [markdown]
# #### Treinamento do modelo

# %%
# Treino do modelo SVM (balanced)
modelo_svm_balanced.fit(
    X_train_tfidf,
    y_train
)
# Out:
# SVC(class_weight='balanced', kernel='linear', random_state=42)

# %% [markdown]
# ### Comparação - Avaliação dos Modelos SVM

# %%
# Predição Modelo SVM (balanced)
y_pred_svm_balanced = modelo_svm_balanced.predict(X_test_tfidf)

# %%
# Métricas de avaliação dos modelos (sem e com class_weight='balanced') 

# Gerando os relatórios como DataFrame
report_baseline = pd.DataFrame(classification_report(y_test, y_pred_svm, output_dict=True)).transpose()
report_balanced = pd.DataFrame(classification_report(y_test, y_pred_svm_balanced, output_dict=True)).transpose()

# Comparando performance dos dois modelos
comparacao = pd.concat([report_baseline, report_balanced], axis=1, keys=['Baseline', 'Balanced'])
comparacao.round(2)
# Out:
#               Baseline                          Balanced                  \
#              precision recall f1-score support precision recall f1-score
# Backend           0.68   0.73     0.71    64.0      0.71   0.69     0.70
# Cloud             0.84   0.79     0.82    48.0      0.84   0.79     0.82
# DataScience       0.81   0.70     0.75    37.0      0.80   0.76     0.78
# Database          0.89   0.87     0.88    54.0      0.89   0.87     0.88
# Frontend          0.76   0.78     0.77    50.0      0.73   0.80     0.76
# Security          0.86   0.90     0.88    60.0      0.86   0.90     0.88
# accuracy          0.80   0.80     0.80     0.8      0.80   0.80     0.80
# macro avg         0.81   0.80     0.80   313.0      0.80   0.80     0.80
# weighted avg      0.80   0.80     0.80   313.0      0.80   0.80     0.80
#
#
#              support
# Backend         64.0
# Cloud           48.0
# DataScience     37.0
# Database        54.0
# Frontend        50.0
# Security        60.0
# accuracy         0.8
# macro avg      313.0
# weighted avg   313.0

# %% [markdown]
# A tabela comparativa mostra que os dois modelos tiveram a mesma acurácia (0.80). No macro avg, o F1-score foi o mesmo (0.80),  o recall médio foi o mesmo (0.80) e a precision média maior (0.81 contra 0.80).
#
# Em `DataScience`, o balanced trouxe: o recall elevou de 0.70 para 0.76,  a precision teve uma leve queda de 0.81 para 0.80, resultando em um F1-score maior (de 0.75 para 0.78).
#
# Em `Backend`, o balanced trouxe: a precision subiu de 0.68 para 0.71, enquanto o recall caiu de 0.73 para 0.69, o F1-score teve uma leve queda de 0.71 para 0.70.
#
# Nas demais categorias, `Frontend` precision caiu de 0.76 para 0.73, o recall teve uma leve alta de 0.78 para 0.80, o F1-score teve uma leve queda 0.77 para 0.76 e o restante obtiveram resultados iguais.
#
# A abordagem Balanced demonstra sua superioridade no nível de classe: elevou o Recall de `DataScience` (0.70 $\rightarrow$ 0.76) e de `Frontend` (0.78 $\rightarrow$ 0.80), além de aumentar a Precisão de `Backend` (0.68 $\rightarrow$ 0.71). Portanto, o reequilíbrio de pesos gerou um modelo mais justo para as classes menores sem degradar o desempenho geral do sistema.

# %% [markdown]
# #### Comparação - Matriz de Confusão

# %%
# Comparando as matrizes de confusão SVM (baseline) vs. (balanced)
cm = confusion_matrix(y_test, y_pred_svm, labels=modelo_svm.classes_)
cm_balanced = confusion_matrix(y_test, y_pred_svm_balanced, labels=modelo_svm_balanced.classes_)

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=modelo_svm.classes_, yticklabels=modelo_svm.classes_,
            ax=axes[0])
axes[0].set_xlabel('Predito')
axes[0].set_ylabel('Real')
axes[0].set_title('SVM (Baseline)')

sns.heatmap(cm_balanced, annot=True, fmt='d', cmap='Blues',
            xticklabels=modelo_svm_balanced.classes_, yticklabels=modelo_svm_balanced.classes_,
            ax=axes[1])
axes[1].set_xlabel('Predito')
axes[1].set_ylabel('Real')
axes[1].set_title('SVM (Balanced)')

plt.tight_layout()
plt.show()

# %% [markdown]
# A comparação entre as matrizes de confusão do modelo SVM (Baseline) e a versão SVM (Balanced) destaca os seguintes pontos:
#
# * Redução dos erros em `Frontend`: Ao aplicar o balanceamento de classes, o modelo reduziu a maior confusão pontual do projeto: os erros onde Frontend era classificado como Backend caíram de 9 para 7 casos, aumentando os acertos de `Frontend` de 39 para 40.
#
# * Melhoria em `DataScience`: A categoria `DataScience` (uma das menores da base) teve um ganho de desempenho, subindo de 26 para 28 acertos, reduzindo falsos negativos para `Backend` (de 5 para 4) e `Cloud` (de 2 para 1).
#
# * Trade-off na classe `Backend`: Para compensar o reequilíbrio das demais classes, a categoria `Backend` teve uma leve queda em seus acertos (de 47 para 44), aumentando seus erros direcionados ao `Frontend` (de 6 para 9 casos).
#
# * Estabilidade nas demais categorias: As classes `Cloud`, `Database` e `Security` mantiveram um desempenho praticamente idêntico em ambas as abordagens.

# %% [markdown]
# Conclusão - Modelo SVM
#
# A inclusão do parâmetro class_weight='balanced' proporcionou um ajuste fino positivo para as classes minoritárias (`DataScience` e `Frontend`) ao custo de uma leve redução na taxa de acertos da classe `Backend`. Isso demonstra o efeito da redistribuição de penalidades do algoritmo, sem impactar o tempo de treinamento do modelo.
#
# Considerando essas informações, o modelo balanced será considerado o modelo final SVM.

# %% [markdown]
# ## Comparação dos Modelos

# %% [markdown]
# AGUARDANDO DESENVOLVIMENTOS DOS DEMAIS MODELOS PARA COMPARAÇÃO

# %% [markdown]
# ## Extração de Palavras-Chave

# %% [markdown]
# A extração das palavras chave é realizada reaproveitando o mesmo vetor TF-IDF aplicado no treinamento do modelo. É possível extrair as palavras mais relevantes do texto, identificando os termos com maior peso (score TF-IDF) para aquele texto específico. Esses termos podem ser utilizados para facilitar buscas, organização e reutilização do conhecimento dentro da plataforma TechMind.

# %%
def extrair_palavras_chave(texto, vectorizer, top_n=5):
    # Transforma o texto em vetor TF-IDF usando o vectorizer já treinado
    tfidf_vector = vectorizer.transform([texto])
    
    # Extrai os pesos TF-IDF do texto (matriz esparsa vira array simples de números)
    scores = tfidf_vector.toarray()[0]

    # Recupera os termos existentes no TF-IDF
    termos = vectorizer.get_feature_names_out()
    
    # Pega os índices dos termos com maior peso, em ordem decrescente
    top_indices = scores.argsort()[-top_n:][::-1]
    
    # Retorna as palavras ordenadas por relevância
    palavras_chave = [termos[i] for i in top_indices if scores[i] > 0]

    # Se quiser ver com o indice
    #palavras_chave = [(termos[i], round(scores[i], 3)) for i in top_indices if scores[i] > 0]
    
    return palavras_chave

# %%
# Testando a extração de palavras-chave em alguns exemplos
resultados = []

for i in range(5):
    texto = X_test.iloc[i]
    categoria = y_test.iloc[i]
    palavras_chave = extrair_palavras_chave(texto, vectorizer, top_n=3)
    resultados.append({'categoria': categoria, 'palavras_chave': palavras_chave})

df_palavras_chave = pd.DataFrame(resultados)
df_palavras_chave
# Out:
#   categoria             palavras_chave
# 0   Backend         [agent, ai, event]
# 1  Frontend     [score, style, option]
# 2     Cloud  [container, azure, ngrok]
# 3   Backend         [ocr, winner, llm]
# 4  Database          [ollama, ai, erd]

# %% [markdown]
# Testando a função de extração de palavras-chave em uma amostra do conjunto de teste, alguns resultados foram coerentes com a categoria real, como Cloud (container, azure, ngrok) e Database (ollama, ai, erd).
#
# Ainda assim, é possível notar sobreposição de vocabulário entre categorias. O termo "ai" aparece tanto em exemplos de Backend quanto de Database, refletindo o quanto certas tecnologias (como IA e LLMs) permeiam múltiplas áreas técnicas. Isso é uma limitação esperada do TF-IDF, que identifica termos estatisticamente relevantes para o texto, mas não necessariamente exclusivos de uma única categoria.

# %% [markdown]
# ## Estrutura do Retorno do Modelo Logistic Regression

# %% [markdown]
# O objetivo é preparar e simular a saída que será consumida pela API da aplicação, reunindo:
#
# - Categoria prevista pelo modelo de classificação;
# - Probabilidade associada à previsão;
# - Palavras-chave extraídas do conteúdo analisado.
#
# Esse teste considera os dados em memória

# %%
# Função simulação 
def analisar_conteudo(texto):
    
    # Transformar texto para o formato do modelo
    texto_tfidf = vectorizer.transform([texto])
    
    # Categoria prevista
    categoria = modelo_lr.predict(texto_tfidf)[0]
    
    # Probabilidade da previsão
    probabilidades = modelo_lr.predict_proba(texto_tfidf)[0]
    probabilidade = float(probabilidades.max())
    
    # Palavras-chave
    palavras_chave = extrair_palavras_chave(
        texto,
        vectorizer,
        top_n=3
    )
    
    return {
        "categoria": str(categoria),
        "probabilidade": round(probabilidade, 2),
        "informacoes_adicionais": palavras_chave
    }

# %%
# definindo texto teste
texto_teste = df_model.loc[0, 'texto']

# %%
# Simulando o retorno
resultado = analisar_conteudo(texto_teste)
resultado
# Out:
# {'categoria': 'Security',
#  'probabilidade': 0.67,
#  'informacoes_adicionais': ['ssh', 'mfa', 'google']}

# %% [markdown]
# ### Análise da Probabilidade de Classificação Logistic Regression

# %%
# Verificando todas as probabilidades do texto teste
probabilidades = modelo_lr.predict_proba(
    vectorizer.transform([texto_teste])
)[0]

df_prob = pd.DataFrame({
    'Categoria': modelo_lr.classes_,
    'Probabilidade': probabilidades
})

df_prob['Probabilidade'] = df_prob['Probabilidade'].round(4)

df_prob = df_prob.sort_values(
    by='Probabilidade',
    ascending=False
)

df_prob
# Out:
#      Categoria  Probabilidade
# 5     Security         0.6682
# 1        Cloud         0.0827
# 0      Backend         0.0823
# 3     Database         0.0678
# 4     Frontend         0.0629
# 2  DataScience         0.0361

# %% [markdown]
# ## Estrutura do Retorno do Modelo SVM (Balanced)

# %%
# Função simulação 
def analisar_conteudo(texto):
    # Transformar texto
    texto_tfidf = vectorizer.transform([texto])
    
    # Categoria prevista
    categoria = modelo_svm_balanced.predict(texto_tfidf)[0]
    
    # Grau de confiança via decision_function + Softmax
    scores = modelo_svm_balanced.decision_function(texto_tfidf)[0]
    exp_scores = np.exp(scores - np.max(scores))  # Estabilidade numérica
    probabilidades = exp_scores / exp_scores.sum()
    probabilidade = float(probabilidades.max())
    
    # Extrair palavras-chave
    palavras_chave = extrair_palavras_chave(texto, vectorizer, top_n=3)
    
    return {
        "categoria": str(categoria),
        "probabilidade": round(probabilidade, 2),
        "informacoes_adicionais": palavras_chave
    }

# %%
# definindo texto teste
texto_teste = df_model.loc[0, 'texto']

# %%
# Simulando o retorno
resultado = analisar_conteudo(texto_teste)
resultado
# Out:
# {'categoria': 'Security',
#  'probabilidade': 0.71,
#  'informacoes_adicionais': ['ssh', 'mfa', 'google']}

# %% [markdown]
# O modelo retorna a distribuição de probabilidades entre todas as classes possíveis. Neste exemplo, a categoria Security apresentou a maior probabilidade de classificação (71%), enquanto as demais categorias apresentaram valores inferiores. Essa informação permite avaliar o nível de confiança associado à previsão realizada pelo modelo.
#
# A probabilidade será utilizada como uma informação adicional no retorno da API, permitindo que aplicações consumidoras tenham visibilidade sobre o grau de confiança da classificação.

# %% [markdown]
# ### Análise da Probabilidade de Classificação SVM (Balanced)

# %%
# Verificando todas as probabilidades do texto teste
scores = modelo_svm_balanced.decision_function(
    vectorizer.transform([texto_teste])
)[0]

# 2. Aplicar Softmax para converter em probabilidades (0 a 1)
exp_scores = np.exp(scores - np.max(scores))  # Evita estouro de memória (underflow/overflow)
probabilidades = exp_scores / exp_scores.sum()

# 3. Montar o DataFrame
df_prob = pd.DataFrame({
    'Categoria': modelo_svm_balanced.classes_,
    'Probabilidade': probabilidades
})

df_prob['Probabilidade'] = df_prob['Probabilidade'].round(4)
df_prob = df_prob.sort_values(by='Probabilidade', ascending=False)

df_prob
# Out:
#      Categoria  Probabilidade
# 5     Security         0.7118
# 1        Cloud         0.1839
# 0      Backend         0.0699
# 3     Database         0.0232
# 4     Frontend         0.0083
# 2  DataScience         0.0028

# %% [markdown]
# ## Serialização do Modelo

# %% [markdown]
# A serialização permite salvar o modelo treinado e o vetor TF-IDF em arquivo persistente, possibilitando que a aplicação Back-End carregue esses componentes sem a necessidade de realizar novamente o treinamento.
#
# Serão armazenados:
#
# - Modelo de classificação (`modelo_lr`);
# - Vetorizador TF-IDF (`vectorizer`).
#
# O arquivo .pkl armazendo será utilizado posteriormente pela API da aplicação Techmind para realizar novas classificações de conteúdos técnicos, juntamente com a extração das palavras-chave e geração das informações de retorno.

# %%
# Gerando arquivo .pkl
artefatos_modelo = {
    "modelo": modelo_lr,
    "vectorizer": vectorizer
}

joblib.dump(
    artefatos_modelo,
    '../modelo/modelo_techmind.pkl'
)
# Out:
# ['../modelo/modelo_techmind.pkl']

# %% [markdown]
# ## Exemplos de Uso (JSON)

# %% [markdown]
# Nesta etapa será simulada a utilização do modelo em um cenário próximo ao funcionamento da API.
#
# Serão enviados exemplos de conteúdos técnicos como entrada, representando requisições realizadas por usuários. O modelo realizará a classificação do conteúdo, calculará a probabilidade da previsão e retornará as palavras-chave identificadas.
#
# A saída será estruturada em formato JSON, seguindo o padrão esperado para integração com a aplicação Backend.

# %%
# Simula o consumo o arquivo .pkl
artefatos = joblib.load('../modelo/modelo_techmind.pkl')

modelo = artefatos["modelo"]
vectorizer = artefatos["vectorizer"]

# %%
# Confirma que os artefatos foram carregados corretamente a partir do .pkl
type(modelo), type(vectorizer)
# Out:
# (sklearn.linear_model._logistic.LogisticRegression,
#  sklearn.feature_extraction.text.TfidfVectorizer)

# %%
# Texto Teste
textos_teste = (
    df_model['texto']
    .sample(3, random_state=42)
    .tolist()
)

textos_teste
# Out:
# ['building dashboard write sql query create report essential organize datum way accurately represent real - world entity capture interaction . process know datum modeling . data model picture - storey building let database building . lets label floor - schema . floor unique identity pair corresponding floor number floor schema- floor schema apartment label table pair unique unit number table- table- forth . apartment unit table different characteristic define size number room . instance schema- studio unit schema- - bedroom unit different floor area . similarly relate table database host schema . organizational blueprint refer data model . schema structure schema typically take structure dictate relationship table inside . star schema . suggest take shape star . setup central table call fact table relationship table call dimension table . fact table explain _ happen _ dimension table give context _ _ . snowflake schema . schema take shape snowflake . dimension table relate subcategorie directly link fact table . table relate table database typically include column uniquely identify record . column refer primary key pk . think unique d distinguish row . table need reference information store table include table primary key column . referenced column know foreign key fk . foreign key establish relationship table allow database connect relate information maintain consistency datum . table contain primary key foreign key step define relationship . relationship tell database table connect enable combine related information query execute . think relationship road connect table relationship retrieve meaningful insight multiple table difficult inefficient . typically type relationship - - relationship relationship suggest record table associate single record table . instance student identity card vice versa . relationship common . - - relationship imply single record table associate multiple record table record second table relate record . example school student student belong school . - - relationship suggest record table associate multiple record table . instance teacher teach student student teach teacher . datum retrieve table organize datum table relate retrieve base different use case join . join combine row table base common column primary key corresponding foreign key . type inner join join return record match value table . instance syntax view student name student table respective school school table attend follow left join join return record left table matching record right table . match exist column right table return null . syntax return student school information miss . right join join reverse left join . return record right table matching record left table . syntax return school student assign . outer join join return record table . matching row combine non - matching row contain null value miss . syntax return record student school table match exist . anti join join return record matching record table . anti join sql native command implement null clause . syntax follow final thought dashboard business application begin - design datum model . understand table relate sql join retrieve combine datum table bring relationship life fundamental skill work datum .',
#  'decade ipv design flaw ipv address follow laptop home network coffee shop airport unchanged build directly network card hardware serial number . ipv address scarce billion total share nat device home office network . laptop phone smart tv appear internet ipv address incidentally provide privacy effect design external server distinguish device address . ipv solve scarcity problem completely address roughly undecillion unique address remove accidental privacy shield . device fully routable globally unique address . question address get generate original answer create bad problem solve . slaac eui- problem stateless address autoconfiguration slaac define rfc let device generate ipv address dhcp server combine -bit network prefix announce router -bit interface identifi . original method generate interface identifier specify rfc s appendix call eui- device -bit mac address split half insert fix value fffe middle flip bit . mac address hardware identifier burn network card manufacture embed directly ipv address device generate network join . bad sound mac - derive interface identifier not change switch network . connect laptop home wi - fi hotel network country conference network bit ipv address stay identical network prefix change . server ad network analytic script log ipv address correlate activity completely unrelated network fix suffix need cooky fingerprinting tracking mechanism . rfc temporary address ietf publish rfc obsoleted supersede rfc refine rfc specifically fix . mechanism commonly call ipv privacy extension generate randomized interface identifi instead mac - derive md - base algorithm seed locally store random value previous identifier rotate schedule rfc s default -hour preferred lifetime -day maximum valid lifetime implementation vary . critically privacy extension generate temporary address outbound connection keep stable address service need reliably reach device like home server accept inbound connection . split matter temporary address external tracker see browse web stable address exist mainly device inbound - reachable service . os land platform default behavior window randomize interface identifier default window move away eui- entirely rotate temporary address . macos ios privacy extension rfc style enable default roughly toggle exist wi - fi setting private address . android randomize addressing enable default android pair - network randomize mac address link layer . linux support net.ipv.conf .. use_tempaddr sysctl historically default distribution networkmanager enable default modern release . privacy extension not fix randomize ipv suffix close specific eui- hardware - track hole not untraceable network layer . -bit network prefix tie isp - assign block coarser real signal usually identify isp day narrow household . tracker correlating request single browse session link mean tls fingerprinting cooky browser fingerprinting regardless ip address . device stable address legitimate reachability reason home nas self - host service design rotate rotation break ability reach . privacy extension solve specific problem address secretly contain permanent hardware fingerprint . mean solve not solve broad question network - layer traceability . check configuration desktop operating system check privacy extension active compare device ipv address mac address interface identifier bit contain fffe middle byte old eui- format device expose hardware - derive permanently trackable suffix . look essentially random relationship mac address privacy extension work . linux ip addr combine sysctl net.ipv.conf.all.use_tempaddr confirm setting directly window macos equivalent check network adapter advanced setting wi - fi privacy toggle respectively . small protocol detail good example privacy problem network tend arrive unintended effect solve completely different problem case address scarcity fix year later work effect actually expose . originally publish havenmessenger.com',
#  'read brief challenge instinct build . fan need navigation help . organizer need oversight . volunteer need coordination . venue staff need operational datum . build app cover instinct wrong figure shape come . pick problem instead challenge explainer session comment stick app try serve persona end serve . deliberate choice narrow scope . flowop ai build exactly person stadium volunteer stand gate try fan move safely match eighty thousand people building . single decision change shape product . instead general dashboard build focused tool thing volunteer actually need moment know crowd build able communicate fan not speak language . make ai actually reason lot ai power app normal dashboard chatbot bolt . want avoid trap core design rule flowop ai simple plain - statement produce output ai not job . instead show volunteer raw number like gate d capacity app ask gemini reason live gate facility datum produce person act immediately . example gate d capacity climb fast gate c nearby elevate share entry point metro station . redirect incoming fan gate e sit comfortably capacity send volunteer intercept queue reach turnstile . s genuinely different kind output percentage bar . explain problem measure . principle apply multilingual assistant . basic translation tool not care ask bathroom report medical emergency . want assistant pick urgency tone swap word language volunteer help distressed fan get different kind translate response help want direction near food stall . let judge bring datum not access real stadium sensor feed app run simulated crowd datum engine mimic gate fill empty time . fully synthetic demo obvious weakness evaluate not tell reasoning actually respond datum recite script . add end call judge override . csv upload feature let drop gate facility datum app immediately swap live feed uploaded dataset pause simulator let ai reasoning respond uploaded . feel important not hide away setting menu . sit right dashboard label control panel point able test reasoning word . bug show tab open interesting problem run not bug traditional sense . architecture gap reveal specific condition multiple browser tab open app . tab run independent crowd simulation write update straight shared database . coordination tab ticker write record overlap moment cause value jump erratically land different gate exactly capacity second . look like data bug concurrency problem . not rule scenario judge open app device teammate open demo change architecture patch symptom . simulated ticker run entirely client write shared database . database reserve specifically sync judge - upload datum happen deliberate user action . small change mean live database reliable sync point thing actually need sync instead share write target open tab . deployment plan change original plan deploy google cloud run . fall apart cloud billing repeatedly reject upi payment method error turn lot developer india run . fail attempt little lost money switch firebase hosting instead not require billing account static build like . hindsight arguably well fit . app firebase database host static frontend mean service configure document give app actually need . d tell start kind build choose narrow problem deep wide . ai simple script genuinely not . build way evaluator test logic input ask trust can demo . infrastructure plan run wall not control not precious original architecture . firebase hosting not plan day get job cost actually need . find source code include project specification file guide build start work similar fifa large scale event tech problem d love hear approach .']

# %%
def analisar_conteudo_api(texto, modelo, vectorizer):
    
    texto_tfidf = vectorizer.transform([texto])
    
    categoria = modelo.predict(texto_tfidf)[0]
    
    probabilidade = modelo.predict_proba(texto_tfidf).max()
    
    palavras_chave = extrair_palavras_chave(
        texto,
        vectorizer,
        top_n=3
    )
    
    return {
        "categoria": str(categoria),
        "probabilidade": float(probabilidade),
        "informacoes_adicionais": palavras_chave
    }

# %%
# Simulando resultado
resultados_json = []

for texto in textos_teste:
    
    resultado = analisar_conteudo_api(
        texto,
        modelo,
        vectorizer
    )
    
    resultados_json.append(resultado)


print(json.dumps(resultados_json, indent=4, ensure_ascii=False))
# Out:
# [
#     {
#         "categoria": "Database",
#         "probabilidade": 0.756231087778829,
#         "informacoes_adicionais": [
#             "table",
#             "relationship",
#             "join"
#         ]
#     },
#     {
#         "categoria": "Security",
#         "probabilidade": 0.4824915213664465,
#         "informacoes_adicionais": [
#             "address",
#             "ipv",
#             "privacy"
#         ]
#     },
#     {
#         "categoria": "Frontend",
#         "probabilidade": 0.2883101334855282,
#         "informacoes_adicionais": [
#             "gate",
#             "fan",
#             "app"
#         ]
#     }
# ]

# %% [markdown]
# Os resultados demonstram que o modelo conseguiu gerar as previsões utilizando os artefatos carregados a partir do arquivo `.pkl`, mantendo a integração entre o modelo de classificação e o vetor TF-IDF utilizado no treinamento.
#
# As probabilidades retornadas indicam o nível de confiança da classificação para cada conteúdo analisado, enquanto as palavras-chave destacam os termos mais relevantes identificados na representação vetorial do texto.
#
# Nos três exemplos testados, o modelo classificou corretamente os temas centrais dos textos: Database (75,6% de confiança, com palavras-chave table, relationship, join), Security (48,2%, com address, ipv, privacy) e Frontend (29%, com gate, fan, app). O terceiro caso, com probabilidade mais baixa, mostra um texto de classificação mais incerta, situação esperada em conteúdos que abordam temas com vocabulário menos exclusivo de uma única categoria.
#
# O retorno já está no formato JSON esperado pela API, pronto para ser consumido pelo backend.

# %% [markdown]
# ## Serialização do Modelo SVM (Balanced)

# %% [markdown]
# A serialização permite salvar o modelo treinado e o vetor TF-IDF em arquivo persistente, possibilitando que a aplicação Back-End carregue esses componentes sem a necessidade de realizar novamente o treinamento.
#
# Serão armazenados:
#
# - Modelo de classificação (`modelo_svm_balanced`);
# - Vetorizador TF-IDF (`vectorizer`).
#
# O arquivo .pkl armazendo será utilizado posteriormente pela API da aplicação Techmind para realizar novas classificações de conteúdos técnicos, juntamente com a extração das palavras-chave e geração das informações de retorno.

# %% [markdown]
# ### Arquivo .pkl

# %%
# Gerando arquivo .pkl
artefatos_modelo = {
    "modelo": modelo_svm_balanced,
    "vectorizer": vectorizer
}

joblib.dump(
    artefatos_modelo,
    '../modelo/modelo_svm_balanced.pkl'
)
# Out:
# ['../modelo/modelo_svm_balanced.pkl']

# %% [markdown]
# ### Arquivo .joblib

# %%
# Gerando arquivo .joblib
artefatos_modelo = {
    "modelo": modelo_svm_balanced,
    "vectorizer": vectorizer
}

joblib.dump(
    artefatos_modelo,
    '../modelo/modelo_svm_balanced.joblib'
)
# Out:
# ['../modelo/modelo_svm_balanced.joblib']

# %% [markdown]
# ### Métricas de comparação pickle vs joblib

# %%
import os
import time
import pickle
import joblib

# 1. Definir os caminhos dos arquivos
caminho_pkl = '../modelo/modelo_svm_balanced.pkl'
caminho_joblib = '../modelo/modelo_svm_balanced.joblib'

# Dicionário com seus artefatos (modelo + vetorizador)
artefatos_modelo = {
    "modelo": modelo_svm_balanced,
    "vectorizer": vectorizer
}

# --- TESTE 1: PICKLE ---
# Tempo de Escrita (Dump)
inicio = time.perf_counter()
with open(caminho_pkl, 'wb') as f:
    pickle.dump(artefatos_modelo, f)
tempo_escrita_pkl = time.perf_counter() - inicio

# Tempo de Leitura (Load)
inicio = time.perf_counter()
with open(caminho_pkl, 'rb') as f:
    _ = pickle.load(f)
tempo_leitura_pkl = time.perf_counter() - inicio

# Tamanho do Arquivo em MB
tamanho_pkl = os.path.getsize(caminho_pkl) / (1024 * 1024)


# --- TESTE 2: JOBLIB ---
# Tempo de Escrita (Dump)
inicio = time.perf_counter()
joblib.dump(artefatos_modelo, caminho_joblib)
tempo_escrita_joblib = time.perf_counter() - inicio

# Tempo de Leitura (Load)
inicio = time.perf_counter()
_ = joblib.load(caminho_joblib)
tempo_leitura_joblib = time.perf_counter() - inicio

# Tamanho do Arquivo em MB
tamanho_joblib = os.path.getsize(caminho_joblib) / (1024 * 1024)


# --- EXIBIÇÃO DA MÉTRICA DE COMPARAÇÃO ---
print(f"{'Métrica':<25} | {'Pickle (.pkl)':<15} | {'Joblib (.joblib)':<15}")
print("-" * 60)
print(f"{'Tamanho do Arquivo (MB)':<25} | {tamanho_pkl:<15.2f} | {tamanho_joblib:<15.2f}")
print(f"{'Tempo de Escrita (s)':<25} | {tempo_escrita_pkl:<15.4f} | {tempo_escrita_joblib:<15.4f}")
print(f"{'Tempo de Leitura (s)':<25} | {tempo_leitura_pkl:<15.4f} | {tempo_leitura_joblib:<15.4f}")
# Out:
# Métrica                   | Pickle (.pkl)   | Joblib (.joblib)
# ------------------------------------------------------------
# Tamanho do Arquivo (MB)   | 3.02            | 3.02
# Tempo de Escrita (s)      | 0.0425          | 0.3339
# Tempo de Leitura (s)      | 0.0303          | 0.1378

# %% [markdown]
# ## Exemplos de Uso (JSON) SVM (Balanced)

# %%
# Simula o consumo o arquivo .pkl
artefatos = joblib.load('../modelo/modelo_svm_balanced.pkl')

modelo = artefatos["modelo"]
vectorizer = artefatos["vectorizer"]

# %%
# Confirma que os artefatos foram carregados corretamente a partir do .pkl
type(modelo), type(vectorizer)
# Out:
# (sklearn.svm._classes.SVC, sklearn.feature_extraction.text.TfidfVectorizer)

# %%
# Texto Teste
textos_teste = (
    df_model['texto']
    .sample(3, random_state=42)
    .tolist()
)

textos_teste
# Out:
# ['building dashboard write sql query create report essential organize datum way accurately represent real - world entity capture interaction . process know datum modeling . data model picture - storey building let database building . lets label floor - schema . floor unique identity pair corresponding floor number floor schema- floor schema apartment label table pair unique unit number table- table- forth . apartment unit table different characteristic define size number room . instance schema- studio unit schema- - bedroom unit different floor area . similarly relate table database host schema . organizational blueprint refer data model . schema structure schema typically take structure dictate relationship table inside . star schema . suggest take shape star . setup central table call fact table relationship table call dimension table . fact table explain _ happen _ dimension table give context _ _ . snowflake schema . schema take shape snowflake . dimension table relate subcategorie directly link fact table . table relate table database typically include column uniquely identify record . column refer primary key pk . think unique d distinguish row . table need reference information store table include table primary key column . referenced column know foreign key fk . foreign key establish relationship table allow database connect relate information maintain consistency datum . table contain primary key foreign key step define relationship . relationship tell database table connect enable combine related information query execute . think relationship road connect table relationship retrieve meaningful insight multiple table difficult inefficient . typically type relationship - - relationship relationship suggest record table associate single record table . instance student identity card vice versa . relationship common . - - relationship imply single record table associate multiple record table record second table relate record . example school student student belong school . - - relationship suggest record table associate multiple record table . instance teacher teach student student teach teacher . datum retrieve table organize datum table relate retrieve base different use case join . join combine row table base common column primary key corresponding foreign key . type inner join join return record match value table . instance syntax view student name student table respective school school table attend follow left join join return record left table matching record right table . match exist column right table return null . syntax return student school information miss . right join join reverse left join . return record right table matching record left table . syntax return school student assign . outer join join return record table . matching row combine non - matching row contain null value miss . syntax return record student school table match exist . anti join join return record matching record table . anti join sql native command implement null clause . syntax follow final thought dashboard business application begin - design datum model . understand table relate sql join retrieve combine datum table bring relationship life fundamental skill work datum .',
#  'decade ipv design flaw ipv address follow laptop home network coffee shop airport unchanged build directly network card hardware serial number . ipv address scarce billion total share nat device home office network . laptop phone smart tv appear internet ipv address incidentally provide privacy effect design external server distinguish device address . ipv solve scarcity problem completely address roughly undecillion unique address remove accidental privacy shield . device fully routable globally unique address . question address get generate original answer create bad problem solve . slaac eui- problem stateless address autoconfiguration slaac define rfc let device generate ipv address dhcp server combine -bit network prefix announce router -bit interface identifi . original method generate interface identifier specify rfc s appendix call eui- device -bit mac address split half insert fix value fffe middle flip bit . mac address hardware identifier burn network card manufacture embed directly ipv address device generate network join . bad sound mac - derive interface identifier not change switch network . connect laptop home wi - fi hotel network country conference network bit ipv address stay identical network prefix change . server ad network analytic script log ipv address correlate activity completely unrelated network fix suffix need cooky fingerprinting tracking mechanism . rfc temporary address ietf publish rfc obsoleted supersede rfc refine rfc specifically fix . mechanism commonly call ipv privacy extension generate randomized interface identifi instead mac - derive md - base algorithm seed locally store random value previous identifier rotate schedule rfc s default -hour preferred lifetime -day maximum valid lifetime implementation vary . critically privacy extension generate temporary address outbound connection keep stable address service need reliably reach device like home server accept inbound connection . split matter temporary address external tracker see browse web stable address exist mainly device inbound - reachable service . os land platform default behavior window randomize interface identifier default window move away eui- entirely rotate temporary address . macos ios privacy extension rfc style enable default roughly toggle exist wi - fi setting private address . android randomize addressing enable default android pair - network randomize mac address link layer . linux support net.ipv.conf .. use_tempaddr sysctl historically default distribution networkmanager enable default modern release . privacy extension not fix randomize ipv suffix close specific eui- hardware - track hole not untraceable network layer . -bit network prefix tie isp - assign block coarser real signal usually identify isp day narrow household . tracker correlating request single browse session link mean tls fingerprinting cooky browser fingerprinting regardless ip address . device stable address legitimate reachability reason home nas self - host service design rotate rotation break ability reach . privacy extension solve specific problem address secretly contain permanent hardware fingerprint . mean solve not solve broad question network - layer traceability . check configuration desktop operating system check privacy extension active compare device ipv address mac address interface identifier bit contain fffe middle byte old eui- format device expose hardware - derive permanently trackable suffix . look essentially random relationship mac address privacy extension work . linux ip addr combine sysctl net.ipv.conf.all.use_tempaddr confirm setting directly window macos equivalent check network adapter advanced setting wi - fi privacy toggle respectively . small protocol detail good example privacy problem network tend arrive unintended effect solve completely different problem case address scarcity fix year later work effect actually expose . originally publish havenmessenger.com',
#  'read brief challenge instinct build . fan need navigation help . organizer need oversight . volunteer need coordination . venue staff need operational datum . build app cover instinct wrong figure shape come . pick problem instead challenge explainer session comment stick app try serve persona end serve . deliberate choice narrow scope . flowop ai build exactly person stadium volunteer stand gate try fan move safely match eighty thousand people building . single decision change shape product . instead general dashboard build focused tool thing volunteer actually need moment know crowd build able communicate fan not speak language . make ai actually reason lot ai power app normal dashboard chatbot bolt . want avoid trap core design rule flowop ai simple plain - statement produce output ai not job . instead show volunteer raw number like gate d capacity app ask gemini reason live gate facility datum produce person act immediately . example gate d capacity climb fast gate c nearby elevate share entry point metro station . redirect incoming fan gate e sit comfortably capacity send volunteer intercept queue reach turnstile . s genuinely different kind output percentage bar . explain problem measure . principle apply multilingual assistant . basic translation tool not care ask bathroom report medical emergency . want assistant pick urgency tone swap word language volunteer help distressed fan get different kind translate response help want direction near food stall . let judge bring datum not access real stadium sensor feed app run simulated crowd datum engine mimic gate fill empty time . fully synthetic demo obvious weakness evaluate not tell reasoning actually respond datum recite script . add end call judge override . csv upload feature let drop gate facility datum app immediately swap live feed uploaded dataset pause simulator let ai reasoning respond uploaded . feel important not hide away setting menu . sit right dashboard label control panel point able test reasoning word . bug show tab open interesting problem run not bug traditional sense . architecture gap reveal specific condition multiple browser tab open app . tab run independent crowd simulation write update straight shared database . coordination tab ticker write record overlap moment cause value jump erratically land different gate exactly capacity second . look like data bug concurrency problem . not rule scenario judge open app device teammate open demo change architecture patch symptom . simulated ticker run entirely client write shared database . database reserve specifically sync judge - upload datum happen deliberate user action . small change mean live database reliable sync point thing actually need sync instead share write target open tab . deployment plan change original plan deploy google cloud run . fall apart cloud billing repeatedly reject upi payment method error turn lot developer india run . fail attempt little lost money switch firebase hosting instead not require billing account static build like . hindsight arguably well fit . app firebase database host static frontend mean service configure document give app actually need . d tell start kind build choose narrow problem deep wide . ai simple script genuinely not . build way evaluator test logic input ask trust can demo . infrastructure plan run wall not control not precious original architecture . firebase hosting not plan day get job cost actually need . find source code include project specification file guide build start work similar fifa large scale event tech problem d love hear approach .']

# %%
def analisar_conteudo_api(texto, modelo, vectorizer):
    
    texto_tfidf = vectorizer.transform([texto])
    
    categoria = modelo.predict(texto_tfidf)[0]
    
    # Pega as distâncias brutas da fronteira de decisão
    scores = modelo.decision_function(texto_tfidf)[0]
    
    # 1. Ajuste de escala para amplificar a diferença entre a classe vencedora e as outras
    # Multiplicar os scores por um fator (ex: 2.0 ou 3.0) ajusta a sensibilidade do Softmax
    scores_scaled = scores * 2.0 
    
    # 2. Softmax estável
    exp_scores = np.exp(scores_scaled - np.max(scores_scaled))
    probabilidades = exp_scores / exp_scores.sum()
    
    probabilidade_max = float(probabilidades.max())
    
    palavras_chave = extrair_palavras_chave(texto, vectorizer, top_n=3)
    
    return {
        "categoria": str(categoria),
        "probabilidade": round(probabilidade_max, 4),  # Mude para 4 casas para ver diferenças finas
        "informacoes_adicionais": palavras_chave
    }

# %%
# Simulando resultado
resultados_json = []

for texto in textos_teste:
    
    resultado = analisar_conteudo_api(
        texto,
        modelo,
        vectorizer
    )
    
    resultados_json.append(resultado)


print(json.dumps(resultados_json, indent=4, ensure_ascii=False))
# Out:
# [
#     {
#         "categoria": "Database",
#         "probabilidade": 0.8884,
#         "informacoes_adicionais": [
#             "table",
#             "relationship",
#             "join"
#         ]
#     },
#     {
#         "categoria": "Security",
#         "probabilidade": 0.897,
#         "informacoes_adicionais": [
#             "address",
#             "ipv",
#             "privacy"
#         ]
#     },
#     {
#         "categoria": "Frontend",
#         "probabilidade": 0.8965,
#         "informacoes_adicionais": [
#             "gate",
#             "fan",
#             "app"
#         ]
#     }
# ]

# %%
# Texto de teste
texto_exemplo = textos_teste[0]

# 1. Verificar se o vetorizador está encontrando palavras
vetor = vectorizer.transform([texto_exemplo])
print("Quantidade de palavras reconhecidas no vocabulário:", vetor.nnz)

# 2. Verificar as distâncias brutas da fronteira de decisão
scores_brutos = modelo.decision_function(vetor)[0]
print("\nClasses do modelo:", modelo.classes_)
print("Scores brutos (distances):", scores_brutos)
# Out:
# Quantidade de palavras reconhecidas no vocabulário: 162
#
# Classes do modelo: ['Backend' 'Cloud' 'DataScience' 'Database' 'Frontend' 'Security']
# Scores brutos (distances): [ 2.85283429  1.7668442   4.2203705   5.29292265  0.74144777 -0.2413561 ]

# %% [markdown]
# ## Conclusões

# %%
# PENDENTE DEMAIS MODELOS
